# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y,yp):
   mae=MAE=sum(abs(y-yp))/len(y)
   return mae




def mean_squared_error(y, y_pred):
   mse=MSE=np.mean((y - y_pred)**2) 
   return mse

# %%
w=3
b=0.5
x_lin=np.linspace(0,100,101)
y=(x_lin+np.random.randn(101)*5)*w+b

plt.plot(x_lin,y,'b.',label='data points')
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat=x_lin*w+b
plt.plot(x_lin,y,'b.',label='data')
plt.plot(x_lin,y_hat,'r-',label='prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
MSE=mean_squared_error(y,y_hat)
MAE=mean_absolute_error(y,y_hat)
print("The MSE is %.3f"%(MSE))
print("The MAE is %.3f"%(MAE))
# Out:
# The MSE is 214.780
# The MAE is 11.329

# %%
作業2
找的是(https://www.kaggle.com/sogun3/uspollution)
1.為何重要
   隨著經濟的發展，各地的污染與日俱增，當然汙染對人類與環境造成的影響被熱烈討論與研究，
    所以分析污染的數據，並針對數據來評估之後地方的發展與後續處理方式是重要的議題
2.資料來源
   All the data is scraped from the database of U.S. EPA :
3.資料型態
   是以excel呈現的結構畫表格資料
4.這組資料想解決的問題如何評估
   把逐年數據匯成表或製作成某些特定數據，清楚顯示排放量上升或下降，根據指標做出相對應手段

# %%
作業三
1.核心問題
   核心問題有可能是知名度或是顧客區隔錯誤之問題，企業目前本身的政策不適用在想要進軍的市場顧客類型
2.資料從何而來
   從車隊載客人數以及顧客類型統整出的數據，以及同業自行求得知數據、政府統計之資料，顧客調查之問卷結果報告
3.資料型態?
   結構化的表格、數值，與非結構化的民意調查、顧客之語音文字等
4.評估問題
   以數據、調查結果來顯示出問題之所在，如果自變數和應變數呈現相關性
